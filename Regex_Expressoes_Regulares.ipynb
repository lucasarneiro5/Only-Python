# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasarneiro5/Only-Python/blob/main/Regex_Expressoes_Regulares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Based on** [Aula de Expressões Regulares do canal -  Eduardo Mendes](https://www.youtube.com/watch?v=AT17Ht87UKI)

# %% [markdown]
# https://www.regexpal.com/

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# Pegar padrão de CPF:

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **OTHERS**
#
# 1.   \b - Word Boundary
# 2.   \B - Not a word Boundary
# 3.

# %%
# Regex library
import re

re.compile('Lucas')
# Out:
# re.compile(r'Lucas', re.UNICODE)

# %%
# Search dá a posicao que estará a string procurada
re.search('a', 'Lucas')
# Out:
# <re.Match object; span=(3, 4), match='a'>

# %%
re.search('a', 'Arara')
# Out:
# <re.Match object; span=(2, 3), match='a'>

# %%
# Match busca somente no inicio
re.match('a', "Lucas")

# %%
#Split
'Lucas'.split('a')
# Out:
# ['Luc', 's']

# %%
# Split do Regex
re.split(r'a', 'Lucas')
# Out:
# ['Luc', 's']

# %%
re.split(r'(c|a)', 'Lucas')
# Out:
# ['Lu', 'c', '', 'a', 's']

# %%
# Findall = Mostra todos os 'a'
re.findall('a|A', 'Arara')
# Out:
# ['A', 'a', 'a']

# %% [markdown]
# **Examples in a Text**

# %%
with open('Tabacaria.txt') as _file:
  text = _file.read()

# %%
olha = re.search(r'Olha', text)
print(olha)
# Out:
# <re.Match object; span=(3457, 3461), match='Olha'>

# %%
print(text[3457:3461])
# Out:
# Olha

# %% [markdown]
# **Getting phone numbers**

# %%
"""from time import sleep
import re
from itertools import permutations

# Valid Celphone Number
cel = re.compile(r'[8-9][0-9]{7}')

# Generate numbers
for tel in permutations(range(1, 10), 8):
  sleep(0.1)
  print(''.join(str(x) for x in tel))
  if cel.search(tel):
    print(tel)"""
# Out:
# "from time import sleep\nimport re\nfrom itertools import permutations\n\n# Valid Celphone Number\ncel = re.compile(r'[8-9][0-9]{7}')\n\n# Generate numbers\nfor tel in permutations(range(1, 10), 8):\n  sleep(0.1)\n  print(''.join(str(x) for x in tel))\n  if cel.search(tel):\n    print(tel)"
